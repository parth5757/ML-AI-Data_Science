# %% [markdown]
# <a href="https://colab.research.google.com/github/parth5757/ML-AI-Data_Science/blob/main/basic_equations_extra_problems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# simple solve for x code

# %%
import sympy
from sympy import symbols
from sympy.solvers import solve

x = symbols('x')

# equation
eq = 2*x + 1

solve(eq, x)
# Out:
# [-1/2]

# %%
import sympy
from sympy import symbols, Eq
from sympy.solvers import solve

x, y = symbols('x, y')

constraint = Eq(x, y)

# equation
eq = Eq(2*x + 3*y + 5, 50)

# a = solve(eq, constraint, x)
# b = solve(eq, constraint, y)
# print(a, b)

# Add an additional constraint (assuming x = y)
constraint = Eq(x, y)

# Solve the system of equations
solution = solve((eq, constraint), (x, y))

# Print the solution
print(f"x = {solution[x]}")
print(f"y = {solution[y]}")
# Out:
# x = 9
# y = 9

# %%
import sympy
from sympy import symbols, Eq
from sympy.solvers import solve

x, y = symbols('x y')

eq1 = Eq(5*x + 4*y + 74, 15500)
solve(eq1, (y))
# print(f"Solution using Eq: {solution1}")
# Out:
# [7713/2 - 5*x/4]

# %%
  import sympy
  from sympy import symbols, Eq
  from sympy.solvers import solve

  # Define the symbols
  x, y = symbols('x y')

  # Define the equation
  eq = Eq(2*x + 3*y + 5, 50)

  # Solve the equation for x and y
  solution = solve((eq, ), (x, y))

  # Print the solution
  print(f"x = {solution[0][0]}")
  print(f"y = {solution[0][1]}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-080701ea2a74> in <cell line: 0>()
#      13
#      14 # Print the solution
# ---> 15 print(f"x = {solution[0][0]}")
#      16 print(f"y = {solution[0][1]}")
#
# KeyError: 0
