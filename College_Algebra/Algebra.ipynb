# %% [markdown]
# <a href="https://colab.research.google.com/github/parth5757/ML-AI-Data_Science/blob/main/College_Algebra/Algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proportions(પ્રમાણ)

# %% [markdown]
# $$
# \frac{2}{4} = \frac{3}{6}
# $$
#
# $$
# \frac{n1}{d1} = \frac{n2}{d2}
# $$

# %% [markdown]
# Question
# $$
# \frac{1}{2} = \frac{?}{16}
# $$
# Answer
# $$
# \frac{1}{2} = \frac{8}{16}
# $$

# %%
# Put Zero in unknown value
n1 = 1
d1 = 2
n2 = 0
d2 = 16

if n2==0:
  print (d2, n1/d1)
  ans = d2* n1 /d1
  print("n2 =", ans)

if d2==0:
  print(n2, d1/n1)
  ans = n2* d1 /n1
  print("d2 =", ans)
# Out:
# 16 0.5
# n2 = 8.0

# %% [markdown]
# $$
# \frac{2}{3}
# $$
# here the 2 over 3 answer will 6.666666666666666 till ∞
# we can take another example
#
# x = .666666
#
# 10x = 6.66666
#
# 9x = 6
#
# so we get value
# $$
# x = \frac{6}{9}
# $$
# & now with simple math calculation we get the
# $$
# x = \frac{2}{3}
# $$

# %%
a = .99999*10
print(a-1)
# Out:
# 8.9999

# %% [markdown]
# let take here another example
#
# x = .4444444
#
# 10x = 4.44444
#
# now we do 10x -1x
#
# so we got 9x = 4
#
# now,
# $$
# x = \frac{4}{9}
# $$
#
# are you show here an intresting fact is that the always in infinite value in this dividend that below value you wuill always get the 9 value suppose you got the it woek any after point 1 to 9 infinite value. & if it is the 9 then value in below and above then you divide it and  you get 1 in answer.
#
# last we take an direct example where we just take
#
# x = .999999
#
# 10x = 9.99999
#
# now we do 10x - 1x & we get
#
# so, 9x = 9
#
# now,
# $$
# x = \frac{9}{9}
# $$
# the final answer is 1

# %% [markdown]
# let take example of USD to INR
#
# $$
# \frac{1USD}{87.40INR}
# $$
#
# So, now we want that the 1INR to USD
#
# $$
# \frac{1USD}{87.40INR} = \frac{?USD}{1INR}
# $$

# %%
1/87.40
# Out:
# 0.011441647597254004

# %% [markdown]
# So, the answer is 0.1144:
#
# Let,s take another example if want to prcatice 1 Mile to 1.6KM

# %% [markdown]
# ## Solving for x
#
# * x + 3 = 5
# * x - 2 = 10
# * 3x = 12
# * $$
# \frac{x}{4}=2
# $$
#
# 1. x + 3 = 5
#
#   -3 = 5 -3
#
# 3-3 = 0 & 5-3 =2
#
# so we get the answer x = 2
#
# 2. x - 2 = 10
#
#     +2 = 10 + 2
#
# so we get the answer x = 12
#
# 3. 3x = 12
# then here can do as following
# $$
# \frac{3x}{3} = \frac{12}{3}
# $$
#
# So, final answer we got is that **4**
#
# 4. $$
# \frac{x}{4}=2
# $$
#
# then here can do as following
#
# $$
# (4)\frac{x}{4}=2(4)
# $$
#
# So, final answer we got is that *8*
#
# Let take another example
#
# x + 7.2 = 11.1
