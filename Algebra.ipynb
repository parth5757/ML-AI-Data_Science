# %% [markdown]
# <a href="https://colab.research.google.com/github/parth5757/ML-AI-Data_Science/blob/main/Algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proportions(પ્રમાણ)

# %% [markdown]
# $$
# \frac{2}{4} = \frac{3}{6}
# $$
#
# $$
# \frac{n1}{d1} = \frac{n2}{d2}
# $$

# %% [markdown]
# Question
# $$
# \frac{1}{2} = \frac{?}{16}
# $$
# Answer
# $$
# \frac{1}{2} = \frac{8}{16}
# $$

# %%
# Put Zero in unknown value
n1 = 1
d1 = 2
n2 = 0
d2 = 16

if n2==0:
  print (d2, n1/d1)
  ans = d2* n1 /d1
  print("n2 =", ans)

if d2==0:
  print(n2, d1/n1)
  ans = n2* d1 /n1
  print("d2 =", ans)
# Out:
# 16 0.5
# n2 = 8.0
